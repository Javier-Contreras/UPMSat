# %%
import pandas as pd
import numpy as np
import math
from cassandra.cluster import Cluster
from sqlalchemy import create_engine

from statsmodels.tsa.seasonal import STL
from pandas.plotting import register_matplotlib_converters
import seaborn as sns

import matplotlib.pyplot as plt

# %% [markdown]
# # Puedes ignorar desde aquí

# %% [markdown]
# ## Datos del csv, los primeros que me envió Alejandro

# %%
df = pd.read_csv (r'/home/javi/Nextcloud/Universidad/Master/TFM/dataset/HK_TM.csv')
df
# Out:
#                   Received Operating_Mode  Misison_Clock  BATT_TBAT1_TM  \
# 0      2020-09-03 23:01:18           SAFE         272036           1653
# 1      2020-09-03 23:02:18           SAFE         272281           1652
# 2      2020-09-03 23:03:58           SAFE         272525           1653
# 3      2020-09-03 23:04:40           SAFE         272770           1653
# 4      2020-09-03 23:05:18           SAFE         273015           1654
# ...                    ...            ...            ...            ...
# 10266  2021-11-24 22:12:07           SAFE      158168074           1680
# 10267  2021-11-24 22:13:46           SAFE      158168319           1676
# 10268  2021-11-24 23:49:27           SAFE      158191862           1643
# 10269  2021-11-24 23:51:27           SAFE      158192352           1645
# 10270  2021-11-24 23:52:07           SAFE      158192597           1646
#
#        BATT_TBAT2_TM  BATT_TBAT3_TM  BATT_VBUS_TM  BATT_VBAT_TM  PSU_T_TM  \
# 0               1645           1641             9          2364      1810
# 1               1647           1641             7          2363      1811
# 2               1646           1641             8          2361      1803
# 3               1646           1642             8          2361      1810
# 4               1646           1642             7          2359      1811
# ...              ...            ...           ...           ...       ...
# 10266           1652           1665             8          2356      1778
# 10267           1646           1661             8          2357      1785
# 10268           1621           1630             8          2485      1778
# 10269           1623           1633             8          2485      1786
# 10270           1624           1634             8          2484      1786
#
#        P3V3_TM  ...  MODEM_VBUS  RW_P5V  RW_VBUS  MTS_VBUS  BOOM1_VBUS  \
# 0          730  ...        True   False     True     False       False
# 1          730  ...        True   False     True     False       False
# 2          730  ...        True   False     True     False       False
# 3          729  ...        True   False     True     False       False
# 4          730  ...        True   False     True     False       False
# ...        ...  ...         ...     ...      ...       ...         ...
# 10266      730  ...        True   False     True     False       False
# 10267      730  ...        True   False     True     False       False
# 10268      730  ...        True   False     True     False       False
# 10269      730  ...        True   False     True     False       False
# 10270      730  ...        True   False     True     False       False
#
#        BOOM2_VBUS  TTC_STAT  SMA_SB01  SMA_SB02  Unnamed: 84
# 0           False     False      True      True          NaN
# 1           False     False      True      True          NaN
# 2           False     False      True      True          NaN
# 3           False     False      True      True          NaN
# 4           False     False      True      True          NaN
# ...           ...       ...       ...       ...          ...
# 10266       False     False      True      True          NaN
# 10267       False     False      True      True          NaN
# 10268       False     False      True      True          NaN
# 10269       False     False      True      True          NaN
# 10270       False     False      True      True          NaN
#
# [10271 rows x 85 columns]

# %% [markdown]
# ## Datos de Cassandra, es necesario exportarlos a csv. Si hago una query directamente solo coge 5000 como máximo.

# %%
df_cassandra = pd.read_csv (r'/home/javi/Nextcloud/Universidad/Master/TFM/cassandra.csv')#, parse_dates=['sequencecount'], index_col='sequencecount')
df_cassandra = df_cassandra[::-1].reset_index()
df_cassandra
# Out:
#        index       tm_type               time_received  batt_t_ext_tm  \
# 0      10270  Housekeeping  2022-02-13 18:31:27.069649           1706
# 1      10269  Housekeeping  2022-02-13 18:31:28.039944           1704
# 2      10268  Housekeeping  2022-02-13 18:31:28.923354           1703
# 3      10267  Housekeeping  2022-02-13 18:31:29.816005           1702
# 4      10266  Housekeeping  2022-02-13 18:31:30.762503           1699
# ...      ...           ...                         ...            ...
# 10266      4  Housekeeping  2022-02-13 20:58:29.852512           1680
# 10267      3  Housekeeping  2022-02-13 20:58:30.676781           1680
# 10268      2  Housekeeping  2022-02-13 20:58:31.506956           1674
# 10269      1  Housekeeping  2022-02-13 20:58:32.333924           1672
# 10270      0  Housekeeping  2022-02-13 20:58:33.163939           1670
#
#        batt_t_int_tm  batt_tbat1_tm  batt_tbat2_tm  batt_tbat3_tm  \
# 0               1705           1653           1645           1645
# 1               1704           1652           1647           1647
# 2               1702           1653           1646           1646
# 3               1701           1653           1646           1646
# 4               1700           1654           1646           1646
# ...              ...            ...            ...            ...
# 10266           1687           1680           1652           1652
# 10267           1685           1676           1646           1646
# 10268           1679           1643           1621           1621
# 10269           1677           1645           1623           1623
# 10270           1676           1646           1624           1624
#
#        batt_vbat_tm  batt_vbus_tm  ... ss6_xn_tm  ss6_xp_tm  ss6_yn_tm  \
# 0              2364             9  ...         5          5          4
# 1              2363             7  ...         5          6          5
# 2              2361             8  ...         5          5          5
# 3              2361             8  ...         5          6          5
# 4              2359             7  ...         5          6          5
# ...             ...           ...  ...       ...        ...        ...
# 10266          2356             8  ...         5          5          5
# 10267          2357             8  ...         5          6          5
# 10268          2485             8  ...         5          5          5
# 10269          2485             8  ...         4          6          5
# 10270          2484             8  ...         5          5          5
#
#       ss6_yp_tm  ss6_zn_tm  ss6_zp_tm  temp_a_p5v  temp_b_p5v           tm_id  \
# 0             5          5          5        True        True  24973552769025
# 1             5          5          6        True        True  75476052804095
# 2             5          6          5        True        True   6840289954733
# 3             5          6          5        True        True  18991407762844
# 4             5          5          6        True        True  11338525550988
# ...         ...        ...        ...         ...         ...             ...
# 10266         5          5          5        True        True  53517918605202
# 10267         5          5          5        True        True  92791483895510
# 10268         5          5          6        True        True  83461232249310
# 10269         5          5          5        True        True  55988488951807
# 10270         5          5          6        True        True   5398510027160
#
#        ttc_stat
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ...         ...
# 10266     False
# 10267     False
# 10268     False
# 10269     False
# 10270     False
#
# [10271 rows x 88 columns]

# %% [markdown]
# ## Los valores de las fechas de los datos en cassandra corresponden a la fecha de entrada en la bbdd, no a la de recepción en tierra

# %%
dates = []
for date in df['Received']:
    dates.append(pd.to_datetime(date, format="%Y/%m/%d %H:%M"))


df_cassandra.time_received=dates
df_cassandra
# Out:
#        index       tm_type       time_received  batt_t_ext_tm  batt_t_int_tm  \
# 0      10270  Housekeeping 2020-09-03 23:01:18           1706           1705
# 1      10269  Housekeeping 2020-09-03 23:02:18           1704           1704
# 2      10268  Housekeeping 2020-09-03 23:03:58           1703           1702
# 3      10267  Housekeeping 2020-09-03 23:04:40           1702           1701
# 4      10266  Housekeeping 2020-09-03 23:05:18           1699           1700
# ...      ...           ...                 ...            ...            ...
# 10266      4  Housekeeping 2021-11-24 22:12:07           1680           1687
# 10267      3  Housekeeping 2021-11-24 22:13:46           1680           1685
# 10268      2  Housekeeping 2021-11-24 23:49:27           1674           1679
# 10269      1  Housekeeping 2021-11-24 23:51:27           1672           1677
# 10270      0  Housekeeping 2021-11-24 23:52:07           1670           1676
#
#        batt_tbat1_tm  batt_tbat2_tm  batt_tbat3_tm  batt_vbat_tm  \
# 0               1653           1645           1645          2364
# 1               1652           1647           1647          2363
# 2               1653           1646           1646          2361
# 3               1653           1646           1646          2361
# 4               1654           1646           1646          2359
# ...              ...            ...            ...           ...
# 10266           1680           1652           1652          2356
# 10267           1676           1646           1646          2357
# 10268           1643           1621           1621          2485
# 10269           1645           1623           1623          2485
# 10270           1646           1624           1624          2484
#
#        batt_vbus_tm  ... ss6_xn_tm  ss6_xp_tm  ss6_yn_tm ss6_yp_tm  ss6_zn_tm  \
# 0                 9  ...         5          5          4         5          5
# 1                 7  ...         5          6          5         5          5
# 2                 8  ...         5          5          5         5          6
# 3                 8  ...         5          6          5         5          6
# 4                 7  ...         5          6          5         5          5
# ...             ...  ...       ...        ...        ...       ...        ...
# 10266             8  ...         5          5          5         5          5
# 10267             8  ...         5          6          5         5          5
# 10268             8  ...         5          5          5         5          5
# 10269             8  ...         4          6          5         5          5
# 10270             8  ...         5          5          5         5          5
#
#        ss6_zp_tm  temp_a_p5v  temp_b_p5v           tm_id  ttc_stat
# 0              5        True        True  24973552769025     False
# 1              6        True        True  75476052804095     False
# 2              5        True        True   6840289954733     False
# 3              5        True        True  18991407762844     False
# 4              6        True        True  11338525550988     False
# ...          ...         ...         ...             ...       ...
# 10266          5        True        True  53517918605202     False
# 10267          5        True        True  92791483895510     False
# 10268          6        True        True  83461232249310     False
# 10269          5        True        True  55988488951807     False
# 10270          6        True        True   5398510027160     False
#
# [10271 rows x 88 columns]

# %% [markdown]
# ## Comprobacion de que los valores de la temperatura de las baterías son los mismos.

# %%
for i in range(0,500):
    csv = df['BATT_TBAT2_TM'][i]
    cassandra = df_cassandra['batt_tbat2_tm'][i]
    if csv != cassandra:
        print("Son diferentes")
        print("CSV: " + str(csv))
        print("Cassandra: " + str(cassandra))
        print(i)

# %% [markdown]
# ## Código para importar los datos directamente de la BBDD

# %%
def pandas_factory(colnames, rows):
    return pd.DataFrame(rows, columns=colnames)

# %%
cluster = Cluster()
session = cluster.connect('upmsat2db')
session.row_factory = pandas_factory

sql_query = "SELECT * FROM housekeeping;"

df_cassandra_biased = pd.DataFrame()


df_cassandra_biased = session.execute(sql_query, timeout=None)._current_rows
df_cassandra_biased.describe()
# Out:
#        batt_t_ext_tm  batt_t_int_tm  batt_tbat1_tm  batt_tbat2_tm  \
# count    5000.000000    5000.000000    5000.000000    5000.000000
# mean     1674.692200    1675.634400    1632.589200    1609.642800
# std        21.338531      19.311751      37.919341      35.484535
# min      1644.000000    1643.000000    1522.000000    1515.000000
# 25%      1658.000000    1663.000000    1618.000000    1591.000000
# 50%      1667.000000    1671.000000    1643.000000    1616.000000
# 75%      1686.000000    1681.000000    1659.000000    1635.000000
# max      1728.000000    1728.000000    1693.000000    1684.000000
#
#        batt_tbat3_tm  batt_vbat_tm  batt_vbus_tm  current_time  ebox_t_ext_tm  \
# count    5000.000000   5000.000000   5000.000000  5.000000e+03     5000.00000
# mean     1609.642800   2493.698400      7.813400  8.908422e+07     1687.93820
# std        35.484535     72.334246      0.676367  3.530887e+07       19.96945
# min      1515.000000   2290.000000      3.000000  4.742823e+07     1659.00000
# 25%      1591.000000   2454.000000      8.000000  5.854619e+07     1672.00000
# 50%      1616.000000   2507.000000      8.000000  7.621312e+07     1682.00000
# 75%      1635.000000   2532.000000      8.000000  1.184523e+08     1699.00000
# max      1684.000000   2703.000000     12.000000  1.581926e+08     1740.00000
#
#        ebox_t_int_tm  ...     rw1_t_tm     rw2_t_tm  sequencecount  \
# count    5000.000000  ...  5000.000000  5000.000000    5000.000000
# mean     1672.812600  ...  1677.275400  1681.508600    7771.500000
# std        18.941669  ...    21.430525    21.254935    1443.520003
# min      1644.000000  ...  1643.000000  1645.000000    5272.000000
# 25%      1659.000000  ...  1660.000000  1665.000000    6521.750000
# 50%      1667.000000  ...  1671.000000  1676.000000    7771.500000
# 75%      1681.000000  ...  1692.250000  1696.000000    9021.250000
# max      1723.000000  ...  1733.000000  1734.000000   10271.000000
#
#          ss6_xn_tm    ss6_xp_tm    ss6_yn_tm    ss6_yp_tm    ss6_zn_tm  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean    116.228800   212.306400   149.690800   155.771400   167.459800
# std     302.350466   387.899043   293.597357   315.107134   332.683889
# min       4.000000     3.000000     4.000000     4.000000     3.000000
# 25%       5.000000     5.000000     5.000000     5.000000     5.000000
# 50%       5.000000     6.000000     5.000000     5.000000     6.000000
# 75%      59.000000   137.250000    72.000000   128.000000   145.000000
# max    1475.000000  1471.000000  1055.000000  1445.000000  1439.000000
#
#          ss6_zp_tm         tm_id
# count  5000.000000  5.000000e+03
# mean    190.829600  5.039149e+13
# std     361.576972  2.875211e+13
# min       1.000000  6.783459e+09
# 25%       5.000000  2.522502e+13
# 50%       6.000000  5.059661e+13
# 75%     164.250000  7.530684e+13
# max    1448.000000  9.997507e+13
#
# [8 rows x 61 columns]

# %% [markdown]
# ## Comprobando si hay valores vacíos en los datos de Cassandra

# %%
columns = list(df_cassandra)
missing_values_str = "df_cassandra["
for column in columns:
    missing_values_str = missing_values_str + "(df_cassandra." + column + ".isna()) | "

missing_values_str = missing_values_str[:-3] + "]"   
eval(missing_values_str)
# Out:
# Empty DataFrame
# Columns: [index, tm_type, time_received, batt_t_ext_tm, batt_t_int_tm, batt_tbat1_tm, batt_tbat2_tm, batt_tbat3_tm, batt_vbat_tm, batt_vbus_tm, battery_status, boom1_vbus, boom2_vbus, current_operating_mode, current_time, das_n15v, das_p15v, das_p3v, das_p5v, ebox_t_ext_tm, ebox_t_int_tm, mgm1_p5v, mgm1_t_tm, mgm1_x_tm, mgm1_y_tm, mgm1_z_tm, mgm2_p5v, mgm2_t_tm, mgm2_x_tm, mgm2_y_tm, mgm2_z_tm, mgm3_n15v, mgm3_p15v, mgm3_t_tm, mgm3_x_tm, mgm3_y_tm, mgm3_z_tm, mgt_tx_tm, mgt_x_vbus, modem_t_tr_tm, modem_vbus, mts_p1tts1_tm, mts_p1tts2_tm, mts_p1tts3_tm, mts_p1tts4_tm, mts_p1tts5_tm, mts_p1tts6_tm, mts_vbus, n15v_tm, obc_t_tm, p15v_tm, p3v3_tm, p5v_tm, pdu_ivbus_tm, pdu_p3v3, pdu_p5v, psu_in15v_tm, psu_ip15v_tm, psu_ip3v3_tm, psu_ip5v_tm, psu_t_tm, pv_ispxn_tm, pv_ispxp_tm, pv_ispyn_tm, pv_ispyp_tm, pv_ispzp_tm, pv_tpsxn_tm, pv_tpsxp_tm, pv_tpsyn_tm, pv_tpsyp_tm, pv_tpszp_tm, rw1_t_tm, rw2_t_tm, rw_p5v, rw_vbus, sequencecount, sma_sb01, sma_sb02, ss6_xn_tm, ss6_xp_tm, ss6_yn_tm, ss6_yp_tm, ss6_zn_tm, ss6_zp_tm, temp_a_p5v, temp_b_p5v, tm_id, ttc_stat]
# Index: []
#
# [0 rows x 88 columns]

# %% [markdown]
# ## Sustutuyendo outliers por la media de sus 4 vecinos

# %%
def knn_mean(ts, n):
    out = np.copy(ts)
    sumat = 0
    for i, val in enumerate(ts):
        if val==4095: #if np.isnan(val):
            for j in range(i-int(n/2),i+int(n/2)+1):
                if j==i:
                    continue
                sumat += out[j]
            
            out[i]= sumat/(n)

            break
    return out

df_cassandra.batt_tbat1_tm =  knn_mean(df_cassandra.batt_tbat1_tm.values, 8)

# %% [markdown]
# # Hasta aquí

# %% [markdown]
# ## Importando datos de CSV

# %%
df = pd.read_csv('/home/javi/Nextcloud/Universidad/Master/TFM/ST_analysis/upmsat.csv')

# %% [markdown]
# ## Cambiando el formato de las fechas de 'str' a 'Timestamp'

# %%
df.time_received = np.array([pd.to_datetime(date, format="%Y/%m/%d %H:%M") for date in df.time_received])

# %%
type(df.time_received[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
#chunk = 2414 # Dos primeros meses
chunk = 1124 # Primer mes
x = df.time_received[:chunk]
y = df.batt_tbat1_tm[:chunk]


plt.rc("figure", figsize=(18, 5))
plt.rc("font", size=13)
plt.plot(x, y)

# %%
register_matplotlib_converters()
sns.set_style("darkgrid")

plt.rc("figure", figsize=(16, 12))
plt.rc("font", size=13)

raw_data = df['batt_tbat1_tm'][:chunk]
dates = dates[:chunk]
data = pd.Series(
    raw_data.values, index=dates, name="Batt_1"
)
stl = STL(data, seasonal=51, period=10)
res = stl.fit()
fig = res.plot()

# %% [markdown]
# ## Calculo de las medias y varianzas en diferentes divisiones de los datos para comprobar su estabilidad

# %%
values = df.batt_tbat1_tm.values[:chunk]
# getting the count to split the dataset into 3
parts = int(len(values)/5)
 
# splitting the data into three parts
part_1, part_2, part_3, part_4, part_5 = values[0:parts], values[parts:(
    parts*2)], values[(parts*2):(parts*3)], values[(parts*3):(parts*4)], values[(parts*4):(parts*5)]
 
# calculating the mean of the separated three
# parts of data individually.
mean_1, mean_2, mean_3, mean_4, mean_5 = part_1.mean(), part_2.mean(), part_3.mean(), part_4.mean(), part_5.mean()
 
# calculating the variance of the separated
# three parts of data individually.
var_1, var_2, var_3, var_4, var_5 = part_1.var(), part_2.var(), part_3.var(), part_4.var(), part_5.var()
 
# printing the mean of three groups
print('mean1=%f, mean2=%f, mean3=%f , mean4=%f , mean5=%f' % (mean_1, mean_2, mean_3, mean_4, mean_5))
 
# printing the variance of three groups
print('variance1=%f, variance2=%f, variance3=%f, variance4=%f, variance5=%f' % (var_1, var_2, var_3, var_4, var_5))
# Out:
# mean1=1661.892857, mean2=1660.745536, mean3=1652.861607 , mean4=1649.562500 , mean5=1644.486607
# variance1=153.408163, variance2=144.350426, variance3=158.815669, variance4=241.960379, variance5=145.633749

# %% [markdown]
# ## Aplicando log al array de valores para suavizar la varianza

# %%
values = df.batt_tbat1_tm.values[:chunk]
values_log = np.array([math.log(value) for value in values])
# getting the count to split the dataset into 3
parts = int(len(values)/5)
 
# splitting the data into three parts
part_1, part_2, part_3, part_4, part_5 = values_log[0:parts], values_log[parts:(
    parts*2)], values_log[(parts*2):(parts*3)], values_log[(parts*3):(parts*4)], values_log[(parts*4):(parts*5)]
 
# calculating the mean of the separated three
# parts of data individually.
mean_1, mean_2, mean_3, mean_4, mean_5 = part_1.mean(), part_2.mean(), part_3.mean(), part_4.mean(), part_5.mean()
 
# calculating the variance of the separated
# three parts of data individually.
var_1, var_2, var_3, var_4, var_5 = part_1.var(), part_2.var(), part_3.var(), part_4.var(), part_5.var()
 
# printing the mean of three groups
print('mean1=%f, mean2=%f, mean3=%f , mean4=%f , mean5=%f' % (mean_1, mean_2, mean_3, mean_4, mean_5))
 
# printing the variance of three groups
print('variance1=%f, variance2=%f, variance3=%f, variance4=%f, variance5=%f' % (var_1, var_2, var_3, var_4, var_5))
# Out:
# mean1=7.415685, mean2=7.414996, mean3=7.410234 , mean4=7.408221 , mean5=7.405157
# variance1=0.000056, variance2=0.000052, variance3=0.000058, variance4=0.000090, variance5=0.000054

# %% [markdown]
# ## Comprobando la estacionalidad con el método adfuller

# %%
from statsmodels.tsa.stattools import adfuller, kpss

# ADF Test
res = adfuller(values)
# Printing the statistical result of the adfuller test
print('Augmneted Dickey_fuller Statistic: %f' % res[0])
print('p-value: %f' % res[1])
# printing the critical values at different alpha levels.
print('critical values at different levels:')
for k, v in res[4].items():
    print('\t%s: %.3f' % (k, v))
    
# KPSS Test
result = kpss(values, regression='c')
print('\nKPSS Statistic: %f' % result[0])
print('p-value: %f' % result[1])
for key, value in result[3].items():
    print('Critial Values:')
    print(f'   {key}, {value}')
# Out:
# Augmneted Dickey_fuller Statistic: -6.114234
# p-value: 0.000000
# critical values at different levels:
# 	1%: -3.436
# 	5%: -2.864
# 	10%: -2.568
#
# KPSS Statistic: 1.720539
# p-value: 0.010000
# Critial Values:
#    10%, 0.347
# Critial Values:
#    5%, 0.463
# Critial Values:
#    2.5%, 0.574
# Critial Values:
#    1%, 0.739
# /home/javi/anaconda3/envs/TFM/lib/python3.9/site-packages/statsmodels/tsa/stattools.py:1998: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   warnings.warn(

# %% [markdown]
# ## Random Walk

# %%
random_walk = []
for i in range(1, len(df)):
    actual_value = df.batt_tbat1_tm[i-1]
    previous_value = df.batt_tbat1_tm[i]
    random_walk.append(actual_value-previous_value)
np.array(random_walk).mean()
# Out:
# 0.0006815968841285297

# %%
register_matplotlib_converters()
sns.set_style("darkgrid")

plt.rc("figure", figsize=(16, 12))
plt.rc("font", size=13)

#raw_data = random_walk[:longitude]
raw_data = [math.log(value) for value in df.batt_tbat1_tm.values][:chunk]
dates = dates[:chunk]
data = pd.Series(
    raw_data, index=dates, name="Batt_1"
)
stl = STL(data, seasonal=51, period=10)
res = stl.fit()
fig = res.plot()

# %%
import pmdarima.arima as arima

arima.ndiffs(df.batt_tbat1_tm.values[:chunk])
# El resultado es 1, hace falta un nivel de diferenciacion
# Out:
# 1

# %%
# ¿Valor de m (número de periodos)?
arima.nsdiffs(df.batt_tbat1_tm.values[:chunk],50)
# Out:
# 0
